# %% [markdown]
# # Text Summarization on Keras Estimator

# %%
# change these to try this notebook out
BUCKET = 'mlend_text_summarization'
PROJECT = 'Fast-ai-DLCodersv3'
REGION = 'us-central1'

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.0.0

# %%
import os
os.environ['BUCKET'] = BUCKET
os.environ['PROJECT'] = PROJECT
os.environ['REGION'] = REGION
os.environ['TFVERSION'] = '2.0.0'

# %% [markdown]
# ## TensorFlow/Keras Code
# Please explore the code in this directory: model.py contains the TensorFlow model and task.py parses command line arguments and launches off the training job.
#
# In particular look for the following:
#
# tf.keras.preprocessing.text.Tokenizer.fit_on_texts() to generate a mapping from our word vocabulary to integers
# tf.keras.preprocessing.text.Tokenizer.texts_to_sequences() to encode our sentences into a sequence of their respective word-integers
# tf.keras.preprocessing.sequence.pad_sequences() to pad all sequences to be the same length
# The embedding layer in the keras model takes care of one-hot encoding these integers and learning a dense emedding represetation from them.
#
# Finally we pass the embedded text representation through a Enoder-Decoder with Attention model

# %% [markdown]
# ### Run Locally (optional step)
# Let's make sure the code compiles by running locally for a fraction of an epoch. This may not work if you don't have all the packages installed locally for gcloud (such as in Colab). This is an optional step; move on to training on the cloud.

# %%
# %%bash
# pip install google-cloud-storage
# rm -rf model_trained
# gcloud ai-platform local train \
#    --module-name=trainer.task \
#    --package-path=${PWD}/model/trainer \
#    -- \
#    --bucket=mlend_text_summarization \
#    --output_dir=${PWD}/model_trained \
#    --train_data_path=data/amazon-fine-food-reviews/ \
#    --eval_data_path=data/amazon-fine-food-reviews/ \
#    --train_filename=train.csv \
#    --eval_filename=validation.csv \
#    --num_epochs=1
# Out:
# ...
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            [(None, 40)]         0
# __________________________________________________________________________________________________
# embedding (Embedding)           (None, 40, 100)      1000100     input_1[0][0]
# __________________________________________________________________________________________________
# lstm (LSTM)                     [(None, 40, 300), (N 481200      embedding[0][0]
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, None)]       0
# __________________________________________________________________________________________________
# lstm_1 (LSTM)                   [(None, 40, 300), (N 721200      lstm[0][0]
# ...
